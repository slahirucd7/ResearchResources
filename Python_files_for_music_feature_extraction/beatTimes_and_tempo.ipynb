# %%
# Beat tracking example
import librosa, matplotlib.pyplot as plt, librosa.display

y, sr = librosa.load("audio/rockYou.wav")

# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)

print('Estimated tempo: {:.2f} beats per minute'.format(tempo))

# 4. Convert the frame indices of beat events into timestamps
beat_times = librosa.frames_to_time(beat_frames, sr=sr)
# Out:
# Estimated tempo: 80.75 beats per minute

# %%
print(beat_times)
# Out:
# [ 0.55727891  1.27709751  2.02013605  2.7631746   3.4829932   4.2492517
#   4.99229025  5.75854875  6.47836735  7.24462585  7.96444444  8.73070295
#   9.45052154 10.19356009 10.91337868 11.67963719 12.39945578 13.16571429
#  13.90875283 14.67501134 15.39482993 16.13786848 16.85768707 17.60072562
#  18.34376417 19.08680272 19.82984127 20.54965986 21.26947846 21.98929705
#  22.75555556 23.47537415 24.2184127  24.96145125 25.7044898  26.44752834
#  27.16734694 27.91038549 28.63020408 29.37324263 30.11628118 30.90575964
#  31.64879819 32.39183673 33.11165533 33.85469388 34.55129252 35.31755102
#  36.06058957 36.80362812 37.52344671 38.26648526 38.98630385 39.75256236
#  40.449161   41.2154195  41.95845805 42.67827664 43.39809524 44.14113379]

# %%
print(beat_times.shape)
# Out:
# (60,)

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, alpha=0.6)
plt.vlines(beat_times, -1, 1, color='r')
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
y.shape
# Out:
# (992780,)

# %%
sr
# Out:
# 22050

# %%
y.shape[0]/sr
# Out:
# 45.024036281179136
